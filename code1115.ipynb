# %%
import os, sys
print("현재 작업 폴더", os.getcwd())
print("현재 폴더 파일/폴더:")
print(os.listdir(".")[:50])
# Out:
# 현재 작업 폴더 c:\Users\gram\anaconda3\envs\bmbd\project
# 현재 폴더 파일/폴더:
# ['GSE30321_series_matrix.txt']

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.0.2

# %%
import pandas as pd
file = "GSE30321_series_matrix.txt"
raw_data = pd.read_csv(file, sep="\t", comment="!", index_col=0)
print("raw shape:", raw_data.shape)
raw_data.iloc[:5, :]
# Out:
# raw shape: (3592, 295)
#                GSM751629  GSM751630  GSM751631  GSM751632  GSM751633  \
# ID_REF
# AB001516_at     4.495407   4.409780   4.369991   4.339823   4.483833
# AB003731_f_at   8.642287   8.627308   8.643501   8.308471   8.663096
# AB003732_f_at   8.793098   8.842475   8.885229   8.331635   8.976496
# AB004109_at     5.731152   5.645404   5.824079   5.899438   5.791065
# AB006130_at     4.455842   4.440362   4.446151   4.478316   4.693045
#
#                GSM751634  GSM751635  GSM751636  GSM751637  GSM751638  ...  \
# ID_REF                                                                ...
# AB001516_at     4.569534   4.678292   4.396043   4.517112   4.463886  ...
# AB003731_f_at   8.685947   8.606731   8.584452   8.512617   8.712685  ...
# AB003732_f_at   8.694223   8.628105   8.829569   8.684361   8.853562  ...
# AB004109_at     5.803290   6.032298   5.940305   5.945695   5.761999  ...
# AB006130_at     4.665515   4.636012   4.398415   4.501857   4.449594  ...
# ...
